# %% [markdown]
# # Predict Future Sales

# %%
# maybe i wanna parse cities and shops locations (like 'ТРЦ')
# check item price distribution (i think i should normilize it)
# check pairs shop-item in train and test data, maybe in train data has no pairs that test has
# last word in items names

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from itertools import product
import datetime

from xgboost import XGBRegressor
from xgboost import plot_importance

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
train_data = pd.read_csv('./Data/sales_train.csv')
test_data = pd.read_csv('./Data/test.csv')
items_data = pd.read_csv('./Data/items.csv')
item_categories_data = pd.read_csv('./Data/item_categories.csv')
shops_data = pd.read_csv('./Data/shops.csv')

# %%
train_data.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
train_data.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
items_data.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
item_categories_data.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
item_categories_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
# item_category_name    84 non-null object
# item_category_id      84 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
item_categories_data
# Out:
#            item_category_name  item_category_id
# 0     PC - Гарнитуры/Наушники                 0
# 1            Аксессуары - PS2                 1
# 2            Аксессуары - PS3                 2
# 3            Аксессуары - PS4                 3
# 4            Аксессуары - PSP                 4
# ..                        ...               ...
# 79                  Служебные                79
# 80         Служебные - Билеты                80
# 81    Чистые носители (шпиль)                81
# 82  Чистые носители (штучные)                82
# 83           Элементы питания                83
#
# [84 rows x 2 columns]

# %%
shops_data.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
train_data.isnull().sum()
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %%
test_data.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
train_data.rename(columns={'item_cnt_day_right': 'item_cnt_month'}, inplace=True)

train_data.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
train_data['date'] = train_data['date'].apply(lambda x:datetime.datetime.strptime(x, '%d.%m.%Y'))

# %%
plt.figure(figsize=(10, 6))

plt.title('Item sales per day (boxplot)')
sns.boxplot(x='item_cnt_day', data=train_data)

# %%
plt.figure(figsize=(10, 6))

plt.title('Item price distribution (boxplot)')
sns.boxplot(x='item_price', data=train_data)

# %%
train_data = train_data.loc[train_data['item_cnt_day'] < 1001]
train_data = train_data.loc[train_data['item_price'] < 50000]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2935845 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              datetime64[ns]
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 156.8 MB

# %%
print('Count of items in train set: ', len(train_data['item_id'].unique()))
print('Count of items in test set: ', len(train_data['item_id'].unique()))
print('Count of shops in train set: ', len(train_data['shop_id'].unique()))
print('Count of shops in test set: ', len(train_data['shop_id'].unique()))
print('Count of items in test set that are not in train set: ', len(set(test_data['item_id'])) - len(set(train_data['item_id']).intersection(set(test_data['item_id']))))
print('Count of shops in test set that are not in train set: ', len(set(test_data['shop_id'])) - len(set(train_data['shop_id']).intersection(set(test_data['shop_id']))))
# Out:
# Count of items in train set:  21805
# Count of items in test set:  21805
# Count of shops in train set:  60
# Count of shops in test set:  60
# Count of items in test set that are not in train set:  363
# Count of shops in test set that are not in train set:  0

# %%
shops_data['shop_name']
# Out:
# 0                       !Якутск Орджоникидзе, 56 фран
# 1                       !Якутск ТЦ "Центральный" фран
# 2                                    Адыгея ТЦ "Мега"
# 3                      Балашиха ТРК "Октябрь-Киномир"
# 4                            Волжский ТЦ "Волга Молл"
# 5                              Вологда ТРЦ "Мармелад"
# 6                          Воронеж (Плехановская, 13)
# 7                              Воронеж ТРЦ "Максимир"
# 8                        Воронеж ТРЦ Сити-Парк "Град"
# 9                                   Выездная Торговля
# 10                         Жуковский ул. Чкалова 39м?
# 11                         Жуковский ул. Чкалова 39м²
# 12                                Интернет-магазин ЧС
# 13                                Казань ТЦ "Бехетле"
# 14                            Казань ТЦ "ПаркХаус" II
# 15                               Калуга ТРЦ "XXI век"
# 16                                   Коломна ТЦ "Рио"
# ...

# %%
shops_data['city'] = shops_data['shop_name'].apply(lambda x: x.split()[0])
shops_data.drop('shop_name', axis=1, inplace=True)

# %%
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = train_data[train_data.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), items_data['item_id'].unique()))))
    
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)

# %%
group = train_data.groupby(['date_block_num', 'shop_id', 'item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

train_data = pd.merge(train_data, group, on=['date_block_num', 'shop_id', 'item_id'])

train_data = pd.merge(matrix, train_data, on=['date_block_num', 'shop_id', 'item_id'], how='left')
train_data['item_cnt_month'] = (train_data['item_cnt_month']
                                .fillna(0)
                                .clip(0,20) # NB clip target here
                                .astype(np.float16))

# %%
train_data = pd.merge(train_data, items_data[['item_id', 'item_category_id']], on='item_id')
train_data['item_price'] = train_data.groupby('item_id')['item_price'].agg(np.max)
train_data['item_price'] = train_data.groupby('item_category_id')['item_price'].apply(lambda x: x.fillna(x.mean()))
train_data['item_price'].fillna(train_data['item_price'].mean(), inplace=True)

# %%
train_data['item_price'].isnull().sum()
# Out:
# 0

# %%
print('Count of items in test set that are not in train set: ', len(set(test_data['item_id'])) - len(set(train_data['item_id']).intersection(set(test_data['item_id']))))
# Out:
# Count of items in test set that are not in train set:  0

# %%
plt.figure(figsize=(10, 6))
sns.distplot(train_data['item_cnt_month'])

# %%
#train_data = train_data.join(train_data.groupby(['date_block_num', 'item_id']).aggregate(np.sum)['item_cnt_day'], on=['date_block_num', 'item_id'], rsuffix='_right')

# %%
train_data.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    3.648834e+07  3.648834e+07  3.648834e+07  3.648834e+07  2.935845e+06
# mean     1.640255e+01  3.137246e+01  1.103090e+04  8.723863e+02  1.241903e+00
# std      9.636203e+00  1.729604e+01  6.405053e+03  7.192741e+01  2.292964e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00  5.000000e+00 -2.200000e+01
# 25%      8.000000e+00  1.600000e+01  5.457000e+03  8.723863e+02  1.000000e+00
# 50%      1.700000e+01  3.100000e+01  1.099700e+04  8.723863e+02  1.000000e+00
# 75%      2.400000e+01  4.700000e+01  1.657500e+04  8.723863e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  4.978200e+04  1.000000e+03
#
#        item_cnt_month  item_category_id
# count      36488343.0      3.648834e+07
# mean              NaN      4.599414e+01
# std               0.0      1.608597e+01
# min               0.0      0.000000e+00
# 25%               0.0      3.700000e+01
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='item_cnt_day', data=train_data)

# %%
train_data.drop(['item_cnt_day', 'date'], axis=1, inplace=True)

# %%
train_data.isnull().sum()
# Out:
# date_block_num      0
# shop_id             0
# item_id             0
# item_price          0
# item_cnt_month      0
# item_category_id    0
# dtype: int64
